# %%
import pandas as pd
import numpy as np
import pyarrow
# Out:
# Running cells with 'GreenHub-Farmer (3.14.2) (Python 3.14.2)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'd:/GIT/GreenHub-Farmer/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
df = pd.read_parquet(r'D:\GIT\GreenHub-Farmer\raw_data\devices\part-0000.parquet')
df
# Out:
# ---------------------------------------------------------------------------
# ArrowKeyError                             Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df = pd.read_parquet(r'D:\GIT\GreenHub-Farmer\raw_data\devices\part-0000.parquet')
#       2 df
#
# File d:\GIT\GreenHub-Farmer\.venv\Lib\site-packages\pandas\io\parquet.py:668, in read_parquet(path, engine, columns, storage_options, dtype_backend, filesystem, filters, to_pandas_kwargs, **kwargs)
#     508 @set_module("pandas")
#     509 def read_parquet(
#     510     path: FilePath | ReadBuffer[bytes],
#    (...)    518     **kwargs,
#     519 ) -> DataFrame:
#     520     """
#     521     Load a parquet object from the file path, returning a DataFrame.
#     522
#    (...)    665     1    4    9
#     666     """
# --> 668     impl = get_engine(engine)
#     669     check_dtype_backend(dtype_backend)
#     671     return impl.read(
#     672         path,
#     673         columns=columns,
# ...
